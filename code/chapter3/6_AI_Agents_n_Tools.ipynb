# %% [markdown]
# # AI Agents & Tools
#
# This example is adapted from [LangChain開發手冊(旗標)](https://www.tenlong.com.tw/products/9789863127918) to support LangChain v0.3 and [中央氣象署開放資料平臺](https://opendata.cwa.gov.tw/about/opendata)

# %%
# !pip install langchain langchain_openai langchain_community rich --quiet

# %%
# 匯入套件和金鑰
from google.colab import userdata
from rich import print as pprint
from langchain_openai import ChatOpenAI
chat_model = ChatOpenAI(api_key=userdata.get('OPENAI_API_KEY'))

# %% [markdown]
# ## 5-1 提供搜尋功能的函式

# %% [markdown]
# ### 使用 LangChain 包裝的 API 類別

# %%
# !pip install duckduckgo-search
# Out:
# Requirement already satisfied: duckduckgo-search in /usr/local/lib/python3.10/dist-packages (7.2.1)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search) (8.1.8)
# Requirement already satisfied: primp>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search) (0.10.0)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search) (5.3.0)

# %%
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper

search = DuckDuckGoSearchAPIWrapper()

result = search.results("2023年金馬獎影后是？", 10)

for item in result:
    print(f"標題：{item['title']}\n")
    print(f"摘要：{item['snippet']}\n\n")
# Out:
# 標題：金馬獎2023》金馬60得獎名單：影帝吳慷仁、12歲影后林品彤｜天下雜誌
#
# 摘要：12歲的林品彤以《小曉》成金馬史上最年輕影后，吳慷仁以《富都青年》首次入圍就獲得金馬影帝。 ... 2023年第60屆金馬獎於11月25日在國父紀念館舉行，今年報名作品共有552部。 ... 我一直覺得在台灣是一件很幸福的事情，台灣有全世界有最專業最敬業的劇組 ...
#
#
# 標題：金馬影后丨鍾雪瑩奪金馬獎凱旋回港 阿雪：大家唔使安慰游學修
#
# 摘要：在2019年，演出ViuTV電視劇《教束》，翌年首次主演電影《殺出個黃昏》，亦憑此片獲香港電影金像獎最佳新演員與最佳女配角的提名。 2023年，憑電影《填詞L》入圍第60屆金馬獎最佳女主角，為入行以來首度獲得影后提名，並再獲得香港電影金像獎最佳女主角提名。
#
#
# 標題：金馬61／金馬完整得獎名單 《鬼才之道》獲5獎大贏家 影帝張志勇、影后鍾雪瑩
#
# 摘要：[周刊王CTWANT] 本屆金馬獎由入圍11獎項拿下5獎的《鬼才之道》成為大贏家，囊括最佳原創電影歌曲、最佳視覺效果、最佳動作設計、最佳美術設計 ...
#
#
# 標題：【2023金馬獎】入圍名單!許光漢林柏宏搶影帝，關於我和鬼爭最佳劇情
#
# 摘要：第60屆2023金馬獎入圍名單熱騰騰公佈，各位心目中的金馬60影帝和影后分別是誰呢？ ... 第60屆2023金馬獎入圍名單熱騰騰公佈，各位心目中的金馬60影帝和影后分別是誰呢？ ... 導演傅天余拍出媽媽故事《本日公休》陸小芬20年之隔演活最強台灣歐巴桑; 2023金馬獎 ...
#
#
# 標題：金馬61／鍾雪瑩以《看我今天怎麼說》奪下最佳女主角獎!現場比手語感謝聾人朋友：「沒有你們就沒有這部電影!」 | Juksy 街星
#
# 摘要：恭喜鍾雪瑩憑藉電影《看我今天怎麼說》榮獲第 61 屆金馬獎「最佳女主角獎」!她的演技在這部電影中獲得了高度肯定，成功奪下影后的殊榮。回顧她的演藝之路，2023 年，她憑藉電影《填詞 l》入圍第 60 屆金馬獎最佳女主角，這是她首次獲得金馬獎的影后提名，同年還獲得了香港電影金像獎最佳 ...
#
#
# 標題：金馬影后鍾雪瑩是誰？15歲歌手出道 「辭退轉演員」一戰成名│Tvbs新聞網
#
# 摘要：2023年，又憑電影《填詞l》入圍第60屆金馬獎最佳女主角，為入行以來首度獲得影后提名，其後再獲得香港電影金像獎最佳女主角提名。 最鍾意免費試鏡
#
#
# 標題：金馬60／林青霞獲終身成就獎!從明星到影后「永遠的東方不敗」…婚後不甩被形塑豪門怨婦仍優雅做自己 - 今周刊
#
# 摘要：期間還成功挑戰了《暗戀桃花源》的舞台劇與電影版。林青霞曾以《碧血黃花》、《慧眼識英雄》提名，並以《滾滾紅塵》榮登第27屆金馬獎最佳女主角寶座，去年（2023）第60屆金馬獎更獲頒終身成就獎，對正逢出道50年的她來說別具意義。
#
#
# 標題：金馬61／楊貴媚時隔19年再奪第二座：每位影后心路歷程都很長，唯一共同就是努力再努力|女人我最大
#
# 摘要：第61屆金馬獎頒獎典禮隆重登場，最佳女配角競爭激烈，陸弈靜八度入圍、張榕容四度入圍，劉奕兒則是連續2年角逐最佳女配，是否能在今年開胡備受矚目。楊貴媚時隔19年再登金馬殿堂，以沉澱歲月的精湛演出奪得人生第二座金馬獎、第一座金馬最佳女配角。 金馬獎最佳女配角：楊貴媚睽違19年再 ...
#
#
# 標題：【金马61】《鬼才之道》成最大赢家 中国、香港演员首夺影帝影后 - 亚洲电视新闻
#
# 摘要：回顾她的演艺之路，2023 年，她凭借电影《填词 l》入围第 60 届金马奖最佳女主角，这是她首次获得金马奖的影后提名，同年还获得了香港电影金像奖最佳女主角提名，这些成就无疑证明了她在演艺界的实力和努力。 ...
#
#
# 標題：2023金馬獎頒獎嘉賓超華麗!李安、妻夫木聰、滿島光、林志玲、張艾嘉國際級陣容，閃耀電影最高殿堂
#
# 摘要：2023年金馬獎（金馬60）太值得期待! ... 現在公開超華麗頒獎陣容，國際等級電影人齊聚一堂，每個搭配都是神仙組合呀! ... 北野武、坎城影帝役所廣司、日本影帝妻夫木聰、日本影后滿島光、金馬影帝張震、金馬影后張艾嘉、曾獲金馬獎最佳新演員獎的柯震東 ...

# %%
print(search.run("2023年金馬獎影后是？"))
# Out:
# 12歲的林品彤以《小曉》成金馬史上最年輕影后，吳慷仁以《富都青年》首次入圍就獲得金馬影帝。 ... 2023年第60屆金馬獎於11月25日在國父紀念館舉行，今年報名作品共有552部。 ... 我一直覺得在台灣是一件很幸福的事情，台灣有全世界有最專業最敬業的劇組 ... [周刊王CTWANT] 本屆金馬獎由入圍11獎項拿下5獎的《鬼才之道》成為大贏家，囊括最佳原創電影歌曲、最佳視覺效果、最佳動作設計、最佳美術設計 ... 在2019年，演出ViuTV電視劇《教束》，翌年首次主演電影《殺出個黃昏》，亦憑此片獲香港電影金像獎最佳新演員與最佳女配角的提名。 2023年，憑電影《填詞L》入圍第60屆金馬獎最佳女主角，為入行以來首度獲得影后提名，並再獲得香港電影金像獎最佳女主角提名。 2023年，又憑電影《填詞l》入圍第60屆金馬獎最佳女主角，為入行以來首度獲得影后提名，其後再獲得香港電影金像獎最佳女主角提名。 最鍾意免費試鏡 第60屆2023金馬獎入圍名單熱騰騰公佈，各位心目中的金馬60影帝和影后分別是誰呢？ ... 第60屆2023金馬獎入圍名單熱騰騰公佈，各位心目中的金馬60影帝和影后分別是誰呢？ ... 導演傅天余拍出媽媽故事《本日公休》陸小芬20年之隔演活最強台灣歐巴桑; 2023金馬獎 ...

# %% [markdown]
# ### 串接流程鏈

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from operator import itemgetter, attrgetter
from langchain_core.runnables import (
    RunnableLambda, RunnablePassthrough)

result_template = "請回答問題:{input}\n 以下為搜尋結果{results}"
result_prompt = ChatPromptTemplate.from_template(result_template)
str_parser =  StrOutputParser()

chain = (
    {"results": search.run,"input": RunnablePassthrough()}
    | result_prompt | chat_model | str_parser)
print(chain.invoke("2023年金馬獎影后是？"))
# Out:
# 2023年金馬獎影后是陸小芬。

# %% [markdown]
# ### 將函式包裝成 runnable 物件—工具 (tool)

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_run = DuckDuckGoSearchRun()

# %%
print(f'工具名稱：{search_run.name}')
print(f'工具描述：{search_run.description}')
print(f'工具參數：{search_run.args}')
# Out:
# 工具名稱：duckduckgo_search
# 工具描述：A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# 工具參數：{'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %%
chain = (
    {"results": search_run,"input": RunnablePassthrough()}
    | result_prompt | chat_model | str_parser)
print(chain.invoke("2023年金馬獎影后是？"))
# Out:
# 2023年金馬獎影后是林品彤。

# %% [markdown]
# ## 5-2 讓模型自己選擇工具

# %%
from pydantic import BaseModel, Field
class SearchRun(BaseModel):
    query: str = Field(description="給搜尋引擎的搜尋關鍵字, "
                                   "請使用繁體中文")

# %%
search_run = DuckDuckGoSearchRun(
    name="ddg-search",
    description="使用網路搜尋你不知道的事物",
    args_schema=SearchRun
)

# %%
print(f'工具名稱：{search_run.name}')
print(f'工具描述：{search_run.description}')
print(f'工具參數：{search_run.args}')
# Out:
# 工具名稱：ddg-search
# 工具描述：使用網路搜尋你不知道的事物
# 工具參數：{'query': {'description': '給搜尋引擎的搜尋關鍵字, 請使用繁體中文', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# ### 加入到模型物件中

# %%
model_with_tools = chat_model.bind_tools([search_run])

# %%
from langchain.output_parsers import JsonOutputToolsParser

chain = model_with_tools | JsonOutputToolsParser()
chain.invoke("2023年金馬獎影后是？")
# Out:
# [{'args': {'query': '2023年金馬獎影后是誰'}, 'type': 'ddg-search'}]

# %%
from langchain.output_parsers import JsonOutputKeyToolsParser

chain = model_with_tools | JsonOutputKeyToolsParser(
    key_name="ddg-search"
)
chain.invoke("2023年金馬獎影后是？")
# Out:
# [{'query': '2023年金馬獎影后是誰'}]

# %%
result_chain = (
    chain | itemgetter(0)
    | {"results": search_run,"input": RunnablePassthrough()}
    | result_prompt | chat_model | str_parser)
print(result_chain.invoke("2023年金馬獎影后是？"))
# Out:
# 2023年金馬獎影后是鍾雪瑩。

# %% [markdown]
# ## 5-3 呼叫第三方API

# %% [markdown]
# ### 中央氣象署開放資料平臺
#
# #### 平台使用說明
# (https://opendata.cwa.gov.tw/devManual/insrtuction)
#
# ```
# ※ URL： https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/{dataid}?Authorization={apikey}&format={format}
#
# {dataid} 為資料編號 (參照：資料清單)  ex.F-A0012-001
# {apikey} 為會員帳號對應之授權碼  ex.CWA-1234ABCD-78EF-GH90-12XY-IJKL12345678
# {format} 為資料格式，請參照各資料集頁面確認可下載之檔案格式  ex.XML、CAP、JSON、ZIP、KMZ
#
# ※ 範例：
# https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/F-A0012-001?Authorization=CWA-1234ABCD-78EF-GH90-12XY-IJKL12345678&format=JSON
#
# ```
#
# #### API文件(Swagger)
# (https://opendata.cwa.gov.tw/dist/opendata-swagger.html)

# %%
oweather_key = userdata.get('TW_OPEN_WEATHER_API_KEY')
# TODO: Parameter locationName is not working now. Server will return weather information of all locations
city = '臺北市'
api_url = 'https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=' + oweather_key + '&format=JSON&locationName=' + city + ''

# %%
import requests, json
from langchain.tools import StructuredTool

# %%
ret = requests.get(api_url)
#ret.__dict__
pprint(ret.json())
# Out:
# {
#     'cwaopendata': {
#         '@xmlns': 'urn:cwa:gov:tw:cwacommon:0.1',
#         'identifier': '5bc4f16a-91c4-7412-d68d-ca2e1889bb49',
#         'sender': 'weather@cwa.gov.tw',
#         'sent': '2025-01-11T10:57:02+08:00',
#         'status': 'Actual',
#         'msgType': 'Issue',
#         'source': 'MFC',
#         'dataid': 'C0032-001',
#         'scope': 'Public',
#         'dataset': {
#             'datasetInfo': {
#                 'datasetDescription': '三十六小時天氣預報',
#                 'issueTime': '2025-01-11T11:00:00+08:00',
#                 'update': '2025-01-11T10:57:02+08:00'
#             },
#             'location': [
#                 {
#                     'locationName': '臺北市',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '14', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '14', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '17', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '14', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '新北市',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '14', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '17', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '桃園市',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '16', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '20', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '臺中市',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '多雲', 'parameterValue': '4'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '18', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '15', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '20', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '15', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '12', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '12', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '臺南市',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '多雲', 'parameterValue': '4'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '19', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '16', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '21', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '16', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '12', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '稍有寒意'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '高雄市',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '陰時多雲', 'parameterValue': '6'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '21', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '18', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '22', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '18', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '稍有寒意'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至舒適'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '基隆市',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '14', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '14', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '16', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '14', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '50', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '40', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '新竹縣',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '多雲', 'parameterValue': '4'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '15', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '17', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '新竹市',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '15', 'parameterUnit': 'C'}
#                                 },
# ...
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '15', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '14', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '16', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷至稍有寒意'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '金門縣',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '15', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '11', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '17', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '11', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '9', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '9', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '非常寒冷至寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '非常寒冷至稍有寒意'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     'locationName': '連江縣',
#                     'weatherElement': [
#                         {
#                             'elementName': 'Wx',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '晴時多雲', 'parameterValue': '2'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MaxT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '9', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '13', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'MinT',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '9', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '9', 'parameterUnit': 'C'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '9', 'parameterUnit': 'C'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'CI',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '非常寒冷至寒冷'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '非常寒冷至寒冷'}
#                                 }
#                             ]
#                         },
#                         {
#                             'elementName': 'PoP',
#                             'time': [
#                                 {
#                                     'startTime': '2025-01-11T12:00:00+08:00',
#                                     'endTime': '2025-01-11T18:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-11T18:00:00+08:00',
#                                     'endTime': '2025-01-12T06:00:00+08:00',
#                                     'parameter': {'parameterName': '10', 'parameterUnit': '百分比'}
#                                 },
#                                 {
#                                     'startTime': '2025-01-12T06:00:00+08:00',
#                                     'endTime': '2025-01-12T18:00:00+08:00',
#                                     'parameter': {'parameterName': '0', 'parameterUnit': '百分比'}
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         }
#     }
# }

# %%
def get_weather(city: str):
    # NOTE! the 001 in API URL will cause error:
    #   structuredtool syntaxerror: leading zeros in decimal integer literals are not permitted
    # We need to make 'F-C0032-001' as a standalone string
    api_url = 'https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/' + 'F-C0032-001' + '?Authorization=' + oweather_key + '&format=JSON'
    response = requests.get(str(api_url)).json()
    weather_list = response['cwaopendata']['dataset']['location']
    for loc_weather in weather_list:
        if loc_weather['locationName'] == city:
            element = loc_weather['weatherElement']
            json_obj = {}
            json_obj[city] = []
            for t in range(3):
                pred_obj = {}
                pred_obj['日期'] = element[0]['time'][t]['startTime']
                pred_obj['天氣'] = element[0]['time'][t]['parameter']['parameterName']
                pred_obj['最高溫'] = element[1]['time'][t]['parameter']['parameterName']
                pred_obj['最低溫'] = element[2]['time'][t]['parameter']['parameterName']
                pred_obj['體感溫度'] = element[3]['time'][t]['parameter']['parameterName']
                json_obj[city].append(pred_obj)

            return json_obj

# %%
weather_data = StructuredTool.from_function(
    func=get_weather,
    name="weather-data",
    description="得到台灣縣市天氣資料")

# %%
pprint(weather_data.invoke("臺北市"))
# Out:
# {
#     '臺北市': [
#         {'日期': '2025-01-11T12:00:00+08:00', '天氣': '陰天', '最高溫': '14', '最低溫': '14', '體感溫度': '寒冷'},
#         {'日期': '2025-01-11T18:00:00+08:00', '天氣': '陰天', '最高溫': '14', '最低溫': '13', '體感溫度': '寒冷'},
#         {
#             '日期': '2025-01-12T06:00:00+08:00',
#             '天氣': '晴時多雲',
#             '最高溫': '17',
#             '最低溫': '13',
#             '體感溫度': '寒冷至稍有寒意'
#         }
#     ]
# }

# %%
print(f'工具名稱：{weather_data.name}')
print(f'工具描述：{weather_data.description}')
print(f'工具參數：{weather_data.args}')
# Out:
# 工具名稱：weather-data
# 工具描述：得到台灣縣市天氣資料
# 工具參數：{'city': {'title': 'City', 'type': 'string'}}

# %%
class Weather(BaseModel):
    city: str = Field(description="台灣縣市, 使用繁體中文")

# %%
weather_data = StructuredTool.from_function(
    func=get_weather,
    name="weather-data",
    description="得到台灣縣市天氣資料",
    args_schema=Weather)

# %%
print(f'工具參數：{weather_data.args}')
# Out:
# 工具參數：{'city': {'description': '台灣縣市, 使用繁體中文', 'title': 'City', 'type': 'string'}}

# %%
weather_template = "請彙整縣市一周的天氣資訊{weather}並回答天氣資訊"
weather_prompt = ChatPromptTemplate.from_template(weather_template)
chain = ({"weather": weather_data}
         | weather_prompt | chat_model | str_parser)
print(chain.invoke("新北市"))
# Out:
# 新北市一周的天氣資訊如下：
#
# - 2025-01-11 12:00:00
#   - 天氣：陰天
#   - 最高溫：14°C
#   - 最低溫：13°C
#   - 體感溫度：寒冷
#
# - 2025-01-11 18:00:00
#   - 天氣：陰天
#   - 最高溫：13°C
#   - 最低溫：13°C
#   - 體感溫度：寒冷
#
# - 2025-01-12 06:00:00
#   - 天氣：晴時多雲
#   - 最高溫：17°C
#   - 最低溫：13°C
#   - 體感溫度：寒冷至稍有寒意
#
# 根據天氣資訊，新北市這一周將有陰天和晴時多雲的天氣，最高溫在17°C至14°C之間，最低溫在13°C，體感溫度會比較寒冷。

# %% [markdown]
# ### 多種工具之間的選擇

# %%
tools = [weather_data, search_run]
model_with_tools = chat_model.bind_tools(tools)
tool_map = {tool.name: tool for tool in tools}

# %%
from langchain_core.runnables import RunnablePassthrough

def call_tool(tool_invocation):
    tool = tool_map[tool_invocation["type"]]
    return RunnablePassthrough.assign(
        output=itemgetter("args") | tool)

# %%
call_tool_list = RunnableLambda(call_tool).map()
chain = (model_with_tools
         | JsonOutputToolsParser()
         | call_tool_list)

# %%
chain.invoke("2023金馬獎影帝是誰?新北市天氣又如何?")
# Out:
# [{'args': {'query': '2023金馬獎影帝是誰'},
#   'type': 'ddg-search',
#   'output': '第60屆2023金馬獎頒獎典禮將於11月25日（六）於台北國父紀念館舉行，而2023金馬獎入圍名單也將熱騰騰曝光，其中備受矚目的，則是許光漢與林柏宏都以《關於我和鬼變成家人的那件事》入圍最佳男主角，將與吳慷仁、王柏傑、阮經天一同爭影帝。 第61屆金馬獎頒獎典禮今（23）日晚間7時於台北流行音樂中心舉辦，獲11項提名的《鬼才之道》拿下5個獎項成為最大贏家，金馬影帝及影后則分別由 ... Dec. 6, 2023 14:03. 12歲林品彤演過動兒封最年輕影后 吳慷仁飾聽障人士奪影帝 金馬獎主席李安反應大不同 Nov. 26, 2023 10:16. 第60屆金馬獎得獎名單一覽 Nov. 25, 2023 20:01. 金馬60完整入圍名單!《鬼家人》許光漢、林柏宏雙男主搶影帝 2023第60屆金馬獎得獎名單揭曉! ... 金馬獎2023》金馬60得獎名單：影帝吳慷仁、12歲影后林品彤 ... 我一直覺得在台灣是一件很幸福的事情，台灣有全世界有最專業最敬業的劇組、戲劇工作人員，我常常提醒我自己大家都準備好了，我沒道理不把戲演好，謝謝所有 ... 李雨勳 2023年10月03日 18:28:00. ... 第60屆金馬獎入圍名單今天（3日）公布，今年影帝之爭形成台灣男星相互廝殺的場面，許光漢與林柏宏更以《關於我和鬼變成家人的那件事》一起入圍，相比之下影后之爭出現許多生面孔，其中睽違20年復出大銀幕的陸小芬以 ...'},
#  {'args': {'city': '新北市'},
#   'type': 'weather-data',
#   'output': {'新北市': [{'日期': '2025-01-11T12:00:00+08:00',
#      '天氣': '陰天',
#      '最高溫': '14',
#      '最低溫': '13',
#      '體感溫度': '寒冷'},
#     {'日期': '2025-01-11T18:00:00+08:00',
#      '天氣': '陰天',
#      '最高溫': '13',
#      '最低溫': '13',
#      '體感溫度': '寒冷'},
#     {'日期': '2025-01-12T06:00:00+08:00',
#      '天氣': '晴時多雲',
#      '最高溫': '17',
#      '最低溫': '13',
#      '體感溫度': '寒冷至稍有寒意'}]}}]

# %% [markdown]
# ## 5-4 代理

# %% [markdown]
# ### 快速建立代理

# %%
from langchain_core.prompts import MessagesPlaceholder
from langchain.agents import (
    AgentExecutor, create_openai_tools_agent)

# %%
prompt = ChatPromptTemplate.from_messages([
    ('system','你是一位好助理'),
    ('human','{input}'),
    MessagesPlaceholder(variable_name="agent_scratchpad")
])

# %%
tools = [weather_data, search_run]
agent = create_openai_tools_agent(llm=chat_model,
                                  tools=tools,
                                  prompt=prompt)

# %%
agent_executor = AgentExecutor(agent=agent,
                               tools=tools,
                               verbose=True)

# %%
result = agent_executor.invoke({"input": "2023金馬獎影帝是誰?"
                                         "新北市天氣又如何?"})
print(result['output'])
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `ddg-search` with `{'query': '2023金馬獎影帝是誰'}`
#
#
# 第61屆金馬獎頒獎典禮今（23）日晚間7時於台北流行音樂中心舉辦，獲11項提名的《鬼才之道》拿下5個獎項成為最大贏家，金馬影帝及影后則分別由 ... 第60屆2023金馬獎頒獎典禮將於11月25日（六）於台北國父紀念館舉行，而2023金馬獎入圍名單也將熱騰騰曝光，其中備受矚目的，則是許光漢與林柏宏都以《關於我和鬼變成家人的那件事》入圍最佳男主角，將與吳慷仁、王柏傑、阮經天一同爭影帝。 Dec. 6, 2023 14:03. 12歲林品彤演過動兒封最年輕影后 吳慷仁飾聽障人士奪影帝 金馬獎主席李安反應大不同 Nov. 26, 2023 10:16. 第60屆金馬獎得獎名單一覽 Nov. 25, 2023 20:01. 金馬60完整入圍名單!《鬼家人》許光漢、林柏宏雙男主搶影帝 2023第60屆金馬獎得獎名單揭曉! ... 金馬獎2023》金馬60得獎名單：影帝吳慷仁、12歲影后林品彤 ... 我一直覺得在台灣是一件很幸福的事情，台灣有全世界有最專業最敬業的劇組、戲劇工作人員，我常常提醒我自己大家都準備好了，我沒道理不把戲演好，謝謝所有 ... 內地演員張志勇勇奪金馬獎影帝. 來自內地的張志勇憑《漂亮朋友》成功打敗游學修、有台灣本土的張震和喜翔和來自泰國的Wanlop RUNGKUMJAD，成功勇奪金馬獎影帝寶座。不過張志勇本人並未未有出席頒獎典禮，由導演耿軍代為領獎並且代為發表感言。
# Invoking: `weather-data` with `{'city': '新北市'}`
#
#
# {'新北市': [{'日期': '2025-01-11T12:00:00+08:00', '天氣': '陰天', '最高溫': '14', '最低溫': '13', '體感溫度': '寒冷'}, {'日期': '2025-01-11T18:00:00+08:00', '天氣': '陰天', '最高溫': '13', '最低溫': '13', '體感溫度': '寒冷'}, {'日期': '2025-01-12T06:00:00+08:00', '天氣': '晴時多雲', '最高溫': '17', '最低溫': '13', '體感溫度': '寒冷至稍有寒意'}]}根據搜尋結果顯示，2023年金馬獎影帝是吳慷仁，他在《關於我和鬼變成家人的那件事》中榮獲此殊榮。
#
# 而關於新北市的天氣資料，截至2025年1月11日12:00，新北市的天氣為多雲，最高溫度為14°C，最低溫度為13°C，體感溫度為寒冷。接下來的天氣預測顯示，持續多雲，溫度介於13°C至17°C之間，稍有寒意。
#
# 希望這些資訊對你有幫助！如果你有任何其他問題或需要更多資訊，歡迎告訴我。
#
# > Finished chain.
# 根據搜尋結果顯示，2023年金馬獎影帝是吳慷仁，他在《關於我和鬼變成家人的那件事》中榮獲此殊榮。
#
# 而關於新北市的天氣資料，截至2025年1月11日12:00，新北市的天氣為多雲，最高溫度為14°C，最低溫度為13°C，體感溫度為寒冷。接下來的天氣預測顯示，持續多雲，溫度介於13°C至17°C之間，稍有寒意。
#
# 希望這些資訊對你有幫助！如果你有任何其他問題或需要更多資訊，歡迎告訴我。

# %%
result = agent_executor.invoke({"input": "你好"})
print(result['output'])
# Out:
# > Entering new AgentExecutor chain...
# 你好！有什麼我可以幫忙的嗎？
# 你需要我幫你做什麼？
#
# > Finished chain.
# 你好！有什麼我可以幫忙的嗎？
# 你需要我幫你做什麼？

# %% [markdown]
# ### 工具除錯

# %%
pprint(weather_data.invoke("台北市"))
# Out:
# None

# %%
from langchain_core.tools import ToolException

def get_weather(city: str):
    response = requests.get('https://script.google.com/macros/s/'
    'AKfycbzmeU-mQXx7qjQSDjFCslQeT1OSU6HDRnRg9o3NmtZvD02DDhcO9RcK-'
    f'K2oOn0ZigX5/exec?city={city}')
    if not response.json():
        raise ToolException("參數使用到簡體字, 請更改成繁體字：臺")
    return response.json()

# %%
weather_data = StructuredTool.from_function(
    func=get_weather,
    name="weather-data",
    description="得到台灣縣市天氣資料",
    args_schema=Weather)

weather_data.invoke("台北市")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     973         try:
# --> 974             return complexjson.loads(self.text, **kwargs)
#     975         except JSONDecodeError as e:
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-57-fe4e10c844d8> in <cell line: 7>()
#       5     args_schema=Weather)
#       6
# ----> 7 weather_data.invoke("台北市")
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/tools/base.py in invoke(self, input, config, **kwargs)
#     482     ) -> Any:
#     483         tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 484         return self.run(tool_input, **kwargs)
#     485
#     486     async def ainvoke(
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/tools/base.py in run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     723         if error_to_raise:
#     724             run_manager.on_tool_error(error_to_raise)
# --> 725             raise error_to_raise
#     726         output = _format_output(content, artifact, tool_call_id, self.name, status)
#     727         run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/tools/base.py in run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     691             if config_param := _get_runnable_config_param(self._run):
#     692                 tool_kwargs = tool_kwargs | {config_param: config}
# --> 693             response = context.run(self._run, *tool_args, **tool_kwargs)
#     694             if self.response_format == "content_and_artifact":
#     695                 if not isinstance(response, tuple) or len(response) != 2:
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/tools/structured.py in _run(self, config, run_manager, *args, **kwargs)
#      78             if config_param := _get_runnable_config_param(self.func):
#      79                 kwargs[config_param] = config
# ---> 80             return self.func(*args, **kwargs)
#      81         msg = "StructuredTool does not support sync invocation."
#      82         raise NotImplementedError(msg)
#
# <ipython-input-56-d953fc34eb81> in get_weather(city)
#       5     'AKfycbzmeU-mQXx7qjQSDjFCslQeT1OSU6HDRnRg9o3NmtZvD02DDhcO9RcK-'
#       6     f'K2oOn0ZigX5/exec?city={city}')
# ----> 7     if not response.json():
#       8         raise ToolException("參數使用到簡體字, 請更改成繁體字：臺")
#       9     return response.json()
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     976             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     979
#     980     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
weather_data = StructuredTool.from_function(
    func=get_weather,
    name="weather-data",
    description="得到台灣縣市天氣資料",
    args_schema=Weather,
    handle_tool_error=True
    )

weather_data.invoke("台北市")

# %%
def _handle_error(error: ToolException) -> str:
    return (
        "工具執行過程中出現以下錯誤:"
        + error.args[0]
    )

weather_data = StructuredTool.from_function(
    func=get_weather,
    name="weather-data",
    description="得到台灣縣市天氣資料",
    args_schema=Weather,
    handle_tool_error=_handle_error,
    )

weather_data.invoke("台北市")

# %%
tools = [weather_data,search_run]
agent = create_openai_tools_agent(llm=chat_model,
                                  tools=tools,
                                  prompt=prompt)
agent_executor = AgentExecutor(agent=agent,
                               tools=tools,
                               verbose=True)

# %%
result = agent_executor.invoke({"input": "台北市未來天氣如何?"})
print(result['output'])

# %% [markdown]
# ### 中間步驟

# %%
agent_executor.return_intermediate_steps = True

# %%
result = agent_executor.invoke({'input':'台中市未來一週的天氣？'})

# %%
pprint(result['intermediate_steps'])
